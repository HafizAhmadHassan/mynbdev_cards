# %% [raw]
# ---
# output-file: workshop-how-to-debug-code-in-cplusplus.html
# title: 'Workshop: How to Debug a Code in C++'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This lecture will teach you how you can do debugging code in c++ and make a setting. We have shown example as well.

# %% [markdown]
# ## Prerequisite :
#
# 1. Install Visual Studio in MacOs
# 2. Install required C/C++ extensions
# 3. Create an account in Github
#
# Suggested videos to fulfill (Macos):
#
# [Video 1](https://youtu.be/tCfbi5PF1y0)
#
#
# [Video 2](https://youtu.be/Qw5qjRNlC-Y)

# %% [markdown]
# Note if you are using windows or linux try searching on Youtube to do setup

# %% [markdown]
# ## Video
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/AOVueg2gOqk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Code Cpp
#
# Here is code used in
#
# [Code](https://drive.google.com/drive/folders/1YAXDoflyh7ZDHUDQdujYJsbVsNILE6kZ?usp=share_link)

# %% [markdown]
# ## Resouces
#
# 1. [Blog](https://archives.robigan.com/posts/cpp-tutorial/)
# 2. [Code Link](https://drive.google.com/drive/folders/1YAXDoflyh7ZDHUDQdujYJsbVsNILE6kZ?usp=share_link)

# %% [markdown]
# ## Acknowledgments
# Special Thanks to Sebastian Our Student who created this
